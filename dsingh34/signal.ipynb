# %%
import os
import sys
import csv
import argparse
import operator
import cPickle as pickle
import re
from mpi4py import MPI
from itertools import chain
from collections import defaultdict
from collections import Counter
import numpy as np
import pandas as pd
import wfdb
import matplotlib.pyplot as plt
import datetime
import time

from numods.usefuns import goodstr, AinB, tmdfAfromB, drawline, compSeqScalar, goodfreq, anyinAB
from numods.numio import getsignaldf, getmetadf, gettimedf, getalldata
from numods.sigstats import sigdat_show, location_stats, freq_stats, numofsig_stats, siglen_stats, allsig_stats, rangelens_by_freq_stats
from numods.proctime import givenanondict, packnanoninfo, classifynans, givetimedseq, consecdiff, interpolate, classifyarts

# %%
# signame = "HR"

# %%
# sigdat_show(signame, showcolnames=True, showsigdat=True)

# %%
# print location_stats(signame, True)
# print freq_stats(signame, "s", True)
# print numofsig_stats(signame, True)
# print siglen_stats(signame, True)
# print allsig_stats("r", topn=15, plot=True)

# %%
# import h5py

# %%
# d = gettimedf("HR")

# %%
# hf = h5py.File('data.h5', 'w')
# for i in d.index.values:
#     #dct[i] = d.loc[i]["sequence"]
#     #np.savez_compressed("tmp", i=d.loc[i]["sequence"])
#     hf.create_dataset(i, data=d.loc[i]["sequence"])
# hf.close()

# %%
hr_data = getmetadf("HR")
abp_sys_data = getmetadf("ABP Sys")
abp_dias_data = getmetadf("ABP Dias")
abp_mean_data = getmetadf("ABP Mean")

# %%
col_names = ["proc_signal_lengths"]
count_thresh = [0, 0]

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [50, 50], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [50, 50], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [100, 100], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [100, 100], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [500, 500], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("HR", hr_data, col_names, [500, 500], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [50, 50], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [50, 50], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [100, 100], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [100, 100], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [500, 500], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Sys", abp_sys_data, col_names, [500, 500], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [50, 50], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [50, 50], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [100, 100], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [100, 100], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [500, 500], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Dias", abp_dias_data, col_names, [500, 500], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [50, 50], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [50, 50], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [100, 100], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [100, 100], ["minutes", "minutes"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [500, 500], ["seconds", "seconds"], count_thresh, (12,6))

# %%
_ = rangelens_by_freq_stats("ABP Mean", abp_mean_data, col_names, [500, 500], ["minutes", "minutes"], count_thresh, (12,6))
